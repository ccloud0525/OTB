# %%
import pandas as pd
import numpy as np
import os
import shutil

# %%
data_path = 'forth/ori_all_datasets'
dir_list = os.listdir(data_path)

# %%
#删除所有csv文件，为解压做准备
for dir in dir_list:
    if os.path.isdir(os.path.join(data_path,dir)):
        file_list = os.listdir(os.path.join(data_path,dir))
        for file in file_list:
            if  file.endswith('.csv'):
                os.remove(os.path.join(data_path,dir,file))

#手动解压一下，全选中双击即可

# %%
dataset_path = '8000'
dataset_list = os.listdir(dataset_path)

# %%
os.makedirs('chosen_datasets',exist_ok=True)
for dataset in dataset_list:
    path = os.path.join(dataset_path,dataset)
    dataset_file = pd.read_csv(path)
    if len(dataset_file) > 80:
        shutil.copy(path, os.path.join('chosen_datasets',dataset))

# %%
print(len(chosen_dataset_list))

# %%
def get_all_files_in_directory(directory):
    all_files = []
    for foldername, subfolders, filenames in os.walk(directory):
        for filename in filenames:
            file_path = os.path.join(foldername, filename)
            if file_path.endswith('.csv'):
                all_files.append(file_path)
    return all_files

# %%
directory_path = 'chosen_datasets/单变量序列预测160条'
all_files = get_all_files_in_directory(directory_path)
file_name = []
for file_path in all_files:
    file_name.append(os.path.basename(file_path))

# %%
file_list = os.listdir('chosen_datasets')
for file in file_list:
    if os.path.isfile(os.path.join('chosen_datasets',file)) and file in file_name:
        os.remove(os.path.join('chosen_datasets',file))

# %%
directory_path = 'forth/ori_all_datasets'
all_files = get_all_files_in_directory(directory_path)
dataset_algorithm={}
file_list = os.listdir('chosen_datasets')
for file in file_list:
    if os.path.isfile(os.path.join('chosen_datasets',file)):
        comparison_list = []
        for open_file in all_files:
            data = pd.read_csv(open_file)
            selected_df = data[data['file_name']==file]
            selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
            if not selected_df.empty:
                comparison_list.append(selected_df)
                
        if len(comparison_list) > 0:
            new_comparison_list = sorted(comparison_list,key=lambda x:float(x['smape']))
            df = new_comparison_list[0]
            alg=df.iloc[0,df.columns.get_loc('model_name')]
            dataset_algorithm[file]=alg
# Out:
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:16: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   new_comparison_list = sorted(comparison_list,key=lambda x:float(x['smape']))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))
# /var/folders/vg/gh2tlr8n27b45gtfkwlt1z4r0000gn/T/ipykernel_16842/3890242962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['smape'] = selected_df['smape'].astype(str).str.split(';').apply(lambda x: float(x[0]))

# %%
print(dataset_algorithm)

# %%
directory_path = 'forth/ori_all_datasets'
all_files = get_all_files_in_directory(directory_path)
model_name_list = []

for open_file in all_files:
    data = pd.read_csv(open_file)
    model_name = data['model_name'][0]
    if model_name not in model_name_list:
        model_name_list.append(model_name)

# %%
print(model_name_list)
# Out:
# ['FiLM', 'DLinear', 'MICN', 'TimesNet', 'NLinear', 'darts_nbeatsmodel', 'Triformer', 'darts_tcnmodel', 'PatchTST', 'Crossformer', 'FEDformer', 'Linear', 'darts_nhitsmodel', 'Nonstationary_Transformer', 'Informer', 'darts_blockrnnmodel', 'darts_statsforecastautoets', 'darts_autoarima', 'darts_statsforecastautotheta', 'darts_randomforest', 'darts_kalmanforecaster', 'darts_naivemovingaverage', 'darts_rnnmodel', 'darts_tidemodel', 'darts_naivemean', 'darts_naivedrift', 'darts_xgbmodel', 'darts_linearregressionmodel', 'darts_naiveseasonal', 'darts_lightgbmmodel', 'darts_statsforecastautoces']

# %%
model_name_dict = {
    'FiLM':0, 'DLinear':1, 'MICN':2, 'TimesNet':3, 'NLinear':4, 'darts_nbeatsmodel':5, 'Triformer':6, 'darts_tcnmodel':7, 'PatchTST':8, 'Crossformer':9, 'FEDformer':10, 'Linear':11, 'darts_nhitsmodel':12, 'Nonstationary_Transformer':13, 'Informer':14, 'darts_blockrnnmodel':15, 'darts_statsforecastautoets':16, 'darts_autoarima':17, 'darts_statsforecastautotheta':18, 'darts_randomforest':19, 'darts_kalmanforecaster':20, 'darts_naivemovingaverage':21, 'darts_rnnmodel':22, 'darts_tidemodel':23, 'darts_naivemean':24, 'darts_naivedrift':25, 'darts_xgbmodel':26, 'darts_linearregressionmodel':27, 'darts_naiveseasonal':28, 'darts_lightgbmmodel':29, 'darts_statsforecastautoces':30
}

# %%
dataset_algorithm_one_hot_list = []
for dataset, algorithm in dataset_algorithm.items():
    vector =  [0]*31
    vector[model_name_dict[algorithm]] = 1
    dataset_algorithm_one_hot_list.append((dataset,vector))

np.save('dataset_algorithm.npy', dataset_algorithm_one_hot_list)
